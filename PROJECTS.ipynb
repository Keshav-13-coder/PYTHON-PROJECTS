# %%
#PROJECT 1 ;"CALCULATOR" by_KESHAV.V
import tkinter


root = tkinter.Tk()

input_field = tkinter.Label(root, text='0', width=30)
input_field.grid(row=0, column=1)

root.title('STANDARD CALC')
root.geometry('600x300')

v = tkinter.StringVar()


def button_press():
    print('BUTTON PRESSED IS :', v.get())
    old_data = str(input_field.cget("text"))
    if old_data[0] == '0':
        old_data = old_data[1:]
    new_data = old_data + v.get()
    input_field.config(text=new_data)


def equal():
    old_data = input_field.cget("text")
    new_data = eval(old_data)
    input_field.config(text=new_data)
    print('= ANSWER BUTTON ;')

def clear_fun():
    old_data = input_field.cget("text")
    new_data = str(old_data[:-1])
    input_field.config(text=new_data)  
    

def clearall_fun():
    old_data = input_field.cget("text")
    new_data = str(old_data[-1:0])
    input_field.config(text=0)
    

def clearallf_fun():
    old_data = input_field.cget("text")
    input_field.config(text=0)
    print('TEXT CLEARED  ;')


def done_1():
    old_data = input_field.cget("text")
    input_field.config(text='THANK YOU👋')
    print('FEEDBACK;GOOD')

def done_2():
    old_data = input_field.cget("text")
    input_field.config(text='OK😃')
    print('FEEDBACK;OK')


def tk_1():
    old_data = input_field.cget("text")
    input_field.config(text='I WILL IMPROVE IT👍')   
    print('FEEDBACK;BAD')

def ans():
    old_data = input_field.cget("text")
    input_field.config(text=0)



tkinter.Radiobutton(root, text=0, value=0, variable=v,
                    command=button_press).grid(row=4, column=1)

t = 1
for i in range(1, 4):
    for j in range(3):
        tkinter.Radiobutton(root, text=t, value=t, variable=v,
                            command=button_press).grid(row=i, column=j)
        t = t + 1


tkinter.Radiobutton(root, text='+', value='+', variable=v,
                    command=button_press).grid(row=1, column=4)
tkinter.Radiobutton(root, text='-', value='-', variable=v,
                    command=button_press).grid(row=2, column=4)
tkinter.Radiobutton(root, text='x', value='*', variable=v,
                    command=button_press).grid(row=3, column=4)
tkinter.Radiobutton(root, text='/', value='/', variable=v,
                    command=button_press).grid(row=4, column=4)

tkinter.Radiobutton(root, text='%', value='%', variable=v,
                    command=button_press).grid(row=3, column=3)


tkinter.Radiobutton(root, text='(', value='(', variable=v,
                    command=button_press).grid(row=1, column=3)

tkinter.Radiobutton(root, text=')', value=')', variable=v,
                    command=button_press).grid(row=2, column=3)


tkinter.Radiobutton(root, text='000', value='000', variable=v,
                    command=button_press).grid(row=4, column=5)


tkinter.Radiobutton(root, text='x^2', value='**2', variable=v,
                    command=button_press).grid(row=1, column=5)


tkinter.Radiobutton(root, text='x^3', value='**3', variable=v,
                    command=button_press).grid(row=2, column=5)

tkinter.Radiobutton(root, text='00', value='00', variable=v,
                    command=button_press).grid(row=3, column=5)



tkinter.Radiobutton(root, text='Space', value=' ', variable=v,
                    command=button_press).grid(row=5, column=3)




tkinter.Button(root, text='=',
               command= equal).grid(row=4, column=2)

tkinter.Button(root, text='C',
               command=clear_fun).grid(row=7, column=4)


tkinter.Button(root, text='CE',
               command=clearall_fun).grid(row=7, column=2)


tkinter.Button(root, text='Clear text',
               command=clearallf_fun).grid(row=8, column=3)


tkinter.Radiobutton(root, text='.', value='.', variable=v,
                    command=button_press).grid(row=4, column=3)


tkinter.Button(root, text='GOOD',command=done_1).grid(row=7, column=5)               

tkinter.Button(root, text='OK',command=done_2).grid(row=7, column=6)  

tkinter.Button(root, text='BAD',command=tk_1).grid(row=7, column=7) 

tkinter.Button(root, text='Clear Answer',
               command=ans).grid(row=9, column=3)

def calling(btndetails):
    print(btndetails.cget('text'))


root.mainloop()

# %%
#PROJECT2 ;"STOPWATCH" by_KESHAV.V
import tkinter

root = tkinter.Tk()

root.title('STOPWATCH')
root.geometry('600x300')

time=  tkinter.Label(root, text='00:00:00', width=30)
time.grid(row=0, column=1)

s  = 1
m =  0
h =  0
stop_logic=False
  
def infinite_logic(s,m,h):
    time.config(text=f'0{h}:0{m}:0{s}')
    if s>=10:
     time.config(text=f'0{h}:0{m}:{s}')
    print(s,'sec')
    s=s+1
    if m>=10:
     time.config(text=f'0{h}:{m}:{s}')
     if m>=60:
        m=0
        h = h+1
        time.config(text=f'{h}:0{m}:0{s}')
     if h>=10:
        time.config(text=f'{h}:{m}:{s}')
    str(print('\tmin',m))
    if s>=60:
       s=0
       m=m+1
    global timings
    timings=root.after(1000,infinite_logic,s,m,h)


def fun_start():
     timings=root.after(1000,infinite_logic,s,m,h)
     print('STARTED')

btn2=tkinter.Button(root,text='START',command=lambda sec=s,minute=m,hour=h:infinite_logic(sec,minute,hour));print('PRESS START BUTTON')
btn2.grid(row=1,column=2)

label=  tkinter.Label(root, text='STOP WATCH\n\tby_KESHAV.V', width=17)
label.grid(row=1, column=4)

btn2=tkinter.Button(root,text='Reset & start',command=fun_start)
btn2.grid(row=3,column=1)


def fun_stop():
    root.after_cancel(timings)
    print('STOP BUTTON WAS PRESSED')


def fun_reset():
     root.after_cancel(timings)
     time.config(text='00:00:00')
     global s,m
     s=1
     m=0
     print('RESET BUTTON WAS PRESSED')

def rest_1():
   l=tkinter.Label(root, text='THANK YOU👋', width=30)
   l.grid(row=6, column=0)
   print('FEEDBACK;GOOD')

def rest_2():
   l=tkinter.Label(root, text='OK,thank you😃', width=30)
   l.grid(row=6, column=1)
   print('FEEDBACK;OK')

def rest_3():
   l=tkinter.Label(root, text='I WILL IMPROVE IT👍', width=30)
   l.grid(row=6, column=2)
   print('FEEDBACK;BAD')




tkinter.Button(root, text='GOOD',command=rest_1).grid(row=5, column=0)               

tkinter.Button(root, text='OK',command=rest_2).grid(row=5, column=1)  

tkinter.Button(root, text='BAD',command=rest_3).grid(row=5, column=2)


btn1=tkinter.Button(root,text='RESET',command=fun_reset)
btn1.grid(row=1,column=1)


btn=tkinter.Button(root,text='STOP',command=fun_stop)
btn.grid(row=1,column=0)


root.mainloop()

# %%
#PROJECT3 ;"SCHOOL MANAGEMENT SYSTEM" by_KESHAV.V
import datetime
import mysql.connector

# 1. School management system


# 1. Student's table - S.no(auto_increment),Student Roll Number(int),Class(int),Section(varchar),CSC MARKS(int),MATHS MARKS(int),SCIENCE MARKS(int),LANG. MARKS(int),TAMIL MARKS(int) etc.. 
# 2. teacher table - S.no(auto_increment), Name(varchar),Date of join(date), Salary(int), class(int).
# 3. worker table - S.no(auto_increment), Name(varchar),Date of join(date), Salary(int),gender (char).
# 4. HOD's table - S.no(auto_increment), Name(varchar),Date of join(date), Salary(int), class(int).

# *STUDENTS:
#  add student
#  view data of a student
#  update student details
#  remove student

# *TEACHERS:
#  add teacher
#  view teacher's data
#  update teacher details
#  remove teacher

# *WORKERS:
#  add new workers
#  view worker's data
#  update worker's details 
#  remove worker

# *HOD's:
#  add new HOD's
#  view HOD's data
#  update HOD's details 
#  remove worker


class databaseconnection:

    def connect(self):
        try:
            self.database = mysql.connector.connect(
                host='MANAGER',
                user='root1',
                password='keshav_1',
                database='pro.'
            )
            self.cursor = self.database.cursor()
        except Exception as e:
            print('Database  not got connected ', e)

    def createtable(self, tableName, args):
        try:
            query = f'create table {tableName} ({args})'
            self.cursor.execute(query)
        except Exception as e:
            print('Database  not got connected ', e, type(e).__name__)


    def inserttable(self, tableName, category, args):
        try:
            if category == 'students':
                query = f'insert into {tableName} (studentName,class,section,gender,cscmarks,mathsmarks,sciencemarks) value {args}'
                print("query")
                print(query)
                self.cursor.execute(query)
                self.database.commit()
                print('Table Created')
        except Exception as e:
            print('Database  not got connected ', e, type(e).__name__)

    def selectrow(self, tableName, rollno=False):
        try:
            if not rollno:
                query = f'select * from {tableName}'
            else:
                query = f'select * from {tableName} where RollNumber = {rollno}'

            print("query")
            print(query)
            self.cursor.execute(query)
            print('The Detail is...,:')
            print(self.cursor.fetchall())
        except Exception as e:
            print('Database  not got connected ', e, type(e).__name__)

    def delete1(self,tableName,rollno):
        try:
             query = f'''delete from {tableName} where RollNumber = {rollno}
             set sql_safe_update = 0;'''
             
        except:
            print('Error...')
             
    def update(self,tableName,change,new,rollno1):
        querry = f'update {tableName} set {change}=
         {new} where RollNumber = {rollno1}  '

connect1 = databaseconnection()
print(connect1.database)
print(connect1.cursor)

args1 = '''RollNumber int primary key  auto_increment,
StudentName varchar(255),
Class int,
Section char(2),
gender char(2)
cscmarks int,
mathsmarks int,
sciencemarks int,
langmarks int,
englishmarks int'''



connect1.create_table('STUDENT', args1)
args1 = (18,'Keshav',8 , 'A', 'M', 89, 92, 89,95,99)
connect1.insert_table('STUDENT', "Students", args1)


args2 = ''' RollNumber int primary key  auto_increment,
teacherName varchar(255),
DOJ date,
salary int,
class1 int,
Section varchar(255),
Gender char(4)
'''


connect1.create_table('TEACHER', args2)
args2 = ('SHANTHI', 2010-12-28, 25000,9,'C','F')
connect1.insert_table('TEACHER', "Teachers", args2)


args3 = ''' RollNumber int primary key  auto_increment,
workerName varchar(255),
DOJ_1 date,
salary_1 int,
Gender_1 char(4)
'''

connect1.create_table('WORKER', args3)
args3 = ('Subbu Kumar', 2014-11-25, 25000,'M')
connect1.insert_table('WORKER', "Workers", args3)

args4 = ''' RollNumber int primary key  auto_increment,
hodName varchar(255),
DOJ_2 date,
salary_2 int,
class1 int,
Gender char(4)
'''
connect1.create_table('HOD', args4)
args2 = ('GAUTAMKARTHICK', 2000-10-29,100000,6,'M')
connect1.insert_table('HOD', "Hod", args4)




i = input('WHICH FILE WOULD YOU LIKE TO OPEN\n1.STUDENT\n2.TEACHER\n3.WORKER\n4.HOD\nExit')
ch=['1','2','3','4','Exit','exit','EXIT']
con = True
if i in ch:
   con = False
while con:
    print('You have entered a Wrong Number ,PLEASE ENTER NUMBERS FROM (1-4) based on this;\n1.TO OPEN STUDENT\n2.TO OPEN TEACHER\n3.TO OPEN WORKER\n4.TO OPEN HOD ')
    i1 = input('WHICH FILE WOULD YOU LIKE TO OPEN\n1.STUDENT\n2.TEACHER\n3.WORKER\n4.HOD')
    if i1 in ch:
        con = False




while True:
       i = input("WHICH FILE WOULD YOU LIKE TO OPEN\n1.STUDENT\n2.TEACHER\n3.WORKER\n4.HOD\nExit")
       if i=='1':
          print("YOU HAVE ENTERED THE STUDENT'S FILE")
          while True:
              in1 =input("PRESS NUMBER:\n1. To add student*\n2. To view data of a student*\n3. To update student details*\n4. To remove student*\n5. To view all the student's details\n6. EXIT")
              if in1 =='1':
                  print('YOU HAVE CAME TO ADD A STUDENT;')
                  StudentName = input ('Enter Student name :') 
                  Class = input ('Enter class :') 
                  Section = input ('Enter section :') 
                  gender = input ('Enter gender:') 
                  cscmarks = input ('Enter csc marks:') 
                  mathsmarks = input ('Enter maths marks :') 
                  sciencemarks = input ('Enter science marks:') 
                  langmarks = input ('Enter language marks:') 
                  englishmarks = input ('Enter english marks ')
                  arg=(StudentName,Class,Section,gender,cscmarks,mathsmarks,sciencemarks,langmarks,englishmarks)
                  connect1.insert_table('STUDENT', "Students",arg)
                  break               
              elif in1 =='2':
                print("YOU HAVE CAME TO VIEW A STUDENT'S DETAIL;")
                roll= input('ENTER ROLL NO TO FETCH DATA:') 
                connect1.selectrow('STUDENT', roll)
                break
              elif in1 =='3':
                  print("YOU HAVE CAME TO UPDATE A STUDENT'S DETAIL;")
                  z = input('Press\n1.To change Name\n2.To change Class\n3.To change Section\n4.To change Csc Marks\n5.To change Maths Marks\n6.To change Science Marks\n7.To change language Marks\n8.To change English Marks')
                  if z =='1':
                      print('YOU HAVE COME TO CHANGE THE NAME;')
                      n=input('Enter old Name:')
                      new=input('Enter new name:')
                      r=input('Enter roll no.,:')
                      connect1.update('STUDENT',n,new,r)
                      break
                  elif z == '2':
                      print('YOU HAVE COME TO CHANGE THE CLASS;')
                      n2=input('Enter old Class:')
                      new2=input('Enter new Class:')
                      r2=input('Enter roll no.,:')
                      connect1.update('STUDENT',n2,new2,r2)
                      break
                  elif z == '3':
                      print('YOU HAVE COME TO CHANGE THE SECTION;')
                      n3=input('Enter old Section:')
                      new3=input('Enter new Section:')
                      r3=input('Enter roll no.,:')
                      connect1.update('STUDENT',n3,new3,r3)
                      break
                  elif z == '4':
                      print('YOU HAVE COME TO CHANGE THE CSC MARKS;')
                      n4=input('Enter old CSC MARKS:')
                      new4=input('Enter new CSC MARKS:')
                      r4=input('Enter roll no.,:')
                      connect1.update('STUDENT',n4,new4,r4)
                      break
                  elif z == '5':
                      print('YOU HAVE COME TO CHANGE THE MATHS MARKS;')
                      n5=input('Enter old MATHS MARKS:')
                      new5=input('Enter new MATHS MARKS:')
                      r5=input('Enter roll no.,:')
                      connect1.update('STUDENT',n5,new5,r5)
                      break
                  elif z == '6':
                      print('YOU HAVE COME TO CHANGE THE SCIENCE MARK;')
                      n6=input('Enter old SCIENCE MARKS:')
                      new6=input('Enter new SCIENCE MARKS:')
                      r6=input('Enter roll no.,:')
                      connect1.update('STUDENT',n6,new6,r6)
                      break
                  elif z == '7':
                      print('YOU HAVE COME TO CHANGE THE LANG. MARKS;')
                      n7=input('Enter old LANG. MARKS:')
                      new7=input('Enter new LANG. MARKS:')
                      r7=input('Enter roll no.,:')
                      connect1.update('STUDENT',n7,new7,r7)
                      break
                  elif z == '8':
                      print('YOU HAVE COME TO CHANGE THE ENGLISH MARKS;')
                      n8=input('Enter old ENGLISH MARKS:')
                      new8=input('Enter new ENGLISH MARKS:')
                      r8=input('Enter roll no.,:')
                      connect1.update('STUDENT',n8,new8,r8)
                      break
                  
              elif in1 =='4':
                  print('YOU HAVE CAME TO DELETE A STUDENT;')
                  roll= input('ENTER ROLL NO TO DELETE STUDENT DATA:') 
                  connect1.delete1('STUDENT',roll)
                  break
              elif in1 =='5':
                  print("YOU HAVE CAME TO VIEW ALL THE STUDENT'S DETAILS;")
                  connect1.selectrow('STUDENT')
                  break
              elif in1 =='6':
                  break
          break
       elif i=='2':
         print("YOU HAVE ENTERED THE TEACHER'S FILE")
         while True:
              in2 =input("PRESS NUMBER:\n1. To add teacher*\n2. To view data of a teacher*\n3. To update teacher details*\n4. To remove teacher*\n5. To view all the teacher's details\n6. EXIT")
              if in2 =='1':
                  print('YOU HAVE CAME TO ADD A TEACHER;')
                  teacherName = input('Enter teachername:')
                  DOJ = input('Enter date of join:')
                  salary = input('Enter Salary:')
                  class1 = input('Enter class:')
                  Section = input('Enter section:')
                  Gender = input('Enter gender:')
                  arg_1=(teacherName,DOJ,salary,class1,Section,Gender)
                  connect1.insert_table('TEACHER', "Teachers",arg_1)                                      
              elif in2 =='2':
                  print("YOU HAVE CAME TO VIEW A TEACHER'S DETAILS;")
                  data= input('ENTER ROLL NO./Adm. NO TO FETCH DATA:') 
                  connect1.selectrow('TEACHER', data)
                  break   
              elif in2 =='3':
                  print("YOU HAVE CAME TO UPDATE A TEACHER'S DETAILS ;")
                  k = input('PRESS\n1.To change Name\n2.To change Salary\n3.To change class\n4.To change Section\n5.To change DOB')
                  if k == '1':
                      print('YOU HAVE COME TO CHANGE THE NAME;')
                      n_=input('Enter old Name:')
                      new_=input('Enter new name:')
                      r_=input('Enter roll no.,:')
                      connect1.update('TEACHER',n_,new_,r_)
                      break 
                  if k == '2':
                      print('YOU HAVE COME TO CHANGE THE SALARY;')
                      n_p=input('Enter old Salary:')
                      new_p=input('Enter new Salary:')
                      r_p=input('Enter roll no.,:')
                      connect1.update('TEACHER',n_p,new_p,r_p)
                      break 
                  if k == '3':
                      print('YOU HAVE COME TO CHANGE THE Class ')
                      n_0=input('Enter old Class:')
                      new_0=input('Enter new Class:')
                      r_0=input('Enter roll no.,:')
                      connect1.update('TEACHER',n_0,new_0,r_0)
                      break
                  if k == '4':
                      print('YOU HAVE COME TO CHANGE THE Section ')
                      n_r=input('Enter old Section:')
                      new_r=input('Enter new Section:')
                      r_r=input('Enter roll no.,:')
                      connect1.update('TEACHER',n_r,new_r,r_r)
                      break 
                  if k == '5':
                      print('YOU HAVE COME TO CHANGE THE DOB ')
                      n_o=input('Enter old DOB:')
                      new_o=input('Enter new DOB:')
                      r_o=input('Enter roll no.,:')
                      connect1.update('TEACHER',n_o,new_o,r_o)
                      break                  
              elif in2 =='4':
                  print('YOU HAVE CAME TO DELETE A TEACHER;')
                  rol= input('ENTER ROLL NO TO DELETE ROLL NO. DATA:') 
                  connect1.delete1('TEACHER',rol)
                  break
              elif in2 =='5':
                  print("YOU HAVE CAME TO VIEW ALL THE TEACHER'S DETAILS;")
                  connect1.selectrow('TEACHER')
                  break 
              elif in2 =='6':
                  break
                  
         break       
       elif i=='3':
         print("YOU HAVE ENTERED THE WORKER'S FILE")
         while True:
              in3 =input("PRESS NUMBER:\n1. To add worker*\n2. To view data of a worker*\n3. To update worker details*\n4. To remove worker*\n5.TO view all the worker's details\n6. EXIT")
              if in3 =='1':
                  print('YOU HAVE CAME TO ADD A WORKER;')
                  workerName = input('Enter workerName : ')
                  DOJ_1 = input('Enter date of join :')
                  salary_1 = input('Enter salary : ')
                  Gender_1 = input('Enter gender :')                                     
              elif in3 =='2':
                  print("YOU HAVE CAME TO VIEW A WORKER'S DETAILS;")
                  dataa= input('ENTER RollNumber TO FETCH DATA:') 
                  connect1.selectrow('WORKER', dataa)
                  break   
              elif in3 =='3':
                  print("YOU HAVE CAME TO UPDATE A WORKER'S DETAILS ;")
                  w = input('Press\n1.To change Name\n2.To change salary\n3.To change DOJ')
                  if w == '1':
                      print('YOU HAVE COME TO CHANGE THE NAME ')
                      n_3=input('Enter old Name:')
                      new_3=input('Enter new Name:')
                      r_3=input('Enter roll no.,:')
                      connect1.update('TEACHER',n_3,new_3,r_3)
                      break
                  elif w == '2':
                      print('YOU HAVE COME TO CHANGE THE Salary ')
                      n_j=input('Enter old Salary:')
                      new_j=input('Enter new Salary:')
                      r_j=input('Enter roll no.,:')
                      connect1.update('TEACHER',n_j,new_j,r_j)
                      break
                  elif w == '3':
                      print('YOU HAVE COME TO CHANGE THE DOJ ')
                      n_e=input('Enter old DOJ:')
                      new_e=input('Enter new DOJ:')
                      r_e=input('Enter roll no.,:')
                      connect1.update('TEACHER',n_e,new_e,r_e)
                      break
                  
              elif in3 =='4':
                  print('YOU HAVE CAME TO DELETE A WORKER;')
                  rolli= input('ENTER ROLL NO TO DELETE WORKER DATA:') 
                  connect1.delete1('WORKER',rolli)
                  break
              elif in3 =='5':
                  print('YOU HAVE CAME TO VIEW ALL THE WORKERS DETAILS;')
                  connect1.selectrow('WORKER')
                  break
              elif in3 =='6':
                  break 
         break           
       elif i=='4':
         print("YOU HAVE ENTERED THE HOD'S FILE")
         while True:
              in3 =input("PRESS NUMBER:\n1. TO add a new HOD*\n2. To view data of a HOD*\n3. To update HOD's details*\n4. To remove HOD*\n5.TO view all the HOD's details\n6. EXIT")
              if in3 =='1':
                  print('YOU HAVE CAME TO ADD A HOD')
                  hodName = input('Enter HOD name :')
                  DOJ_2 = input('Enter date of join : ')
                  salary_2 = input('Enter salary :') 
                  class1 = input('Enter class :') 
                  Gender = input('Enter gender :')
                                       
              elif in3 =='2':
                  print("YOU HAVE CAME TO VIEW A HOD'S DETAILS;")
                  dataa1= input('ENTER RollNumber TO FETCH DATA:') 
                  connect1.selectrow('HOD', dataa1)
                  break  
              elif in3 =='3':
                  print("YOU HAVE CAME TO UPDATE A HOD'S DETAILS ;")
                  h = input ('Press\n1.To change name\n2.To change Salary\n3.To change DOJ')
                  if h == '1':
                      print('YOU HAVE COME TO CHANGE THE NAME ')
                      n_c=input('Enter old Name:')
                      new_c=input('Enter new Name:')
                      r_c=input('Enter roll no.,:')
                      connect1.update('TEACHER',n_c,new_c,r_c)
                      break
                  elif h == '2':
                      print('YOU HAVE COME TO CHANGE THE Salary ')
                      n_P=input('Enter old Salary:')
                      new_P=input('Enter new Salary:')
                      r_P=input('Enter roll no.,:')
                      connect1.update('TEACHER',n_P,new_P,r_P)
                      break
                  elif h == '3':
                      print('YOU HAVE COME TO CHANGE THE DOJ ')
                      n_R=input('Enter old DOJ:')
                      new_R=input('Enter new DOJ:')
                      r_R=input('Enter roll no.,:')
                      connect1.update('TEACHER',n_R,new_R,r_R)
                      break
              elif in3 =='4':
                  print('YOU HAVE CAME TO DELETE A HOD')
                  rollik= input('ENTER ROLL NO TO DELETE HOD DATA:') 
                  connect1.delete1('HOD',rollik)
                  break
              elif in3 =='5':
                  print('YOU HAVE CAME TO VIEW ALL THE HOD DETAILS;')
                  connect1.selectrow('HOD')
                  break
              elif in3 =='6':
                  break 
                        
              break
       elif i=='exit' or 'EXIT' or 'Exit':
           break

# %%
#PROJECT4 ;"EMAIL CHECKING CODE" by_KESHAV.V
import re
email = input('Enter Email:')
pattern = ('^[a-z0-9\.?_]+@[a-z0-9\_\-]+\.([a-z]{2,5})$')
match = re.match(pattern,email)
con = True
if match :
  print('VALID EMAIL:',email)
  con = False
else:
  print('INVALID...TRY AGAIN;')  
  while con:
    email = input('Enter CORRECT Email:')
    pattern = ('^[a-z0-9\.?_]+@[a-z0-9\_\-]+\.([a-z]{2,5})$')
    match = re.match(pattern,email)
    if match :
     print('VALID EMAIL:',email)
     con = False
    else:
     print('INVALID...TRY AGAIN;')
